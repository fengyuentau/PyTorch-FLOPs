# %%
import sys
# print(sys.version_info)
assert sys.version_info[0] == 3, 'Major version of Python must be 3 to run this jupyter notebook.'

# %%
import flops_counter
import models

# %% [raw]
# # pyramidbox
# x = flops_counter.TensorSize(1,3,640,640)
# pb = models.PyramidBox()
# y = pb(x)
# # print(pb)
# print(pb.flops)

# %%
# srn
x = flops_counter.TensorSize(1,3,512,512)
srn = models.SRN()
y = srn(x)
print(srn)
# Out:
# SRN(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False), FLOPs = 1,228,931,072, input = flops_counter.TensorSize([1, 3, 512, 512]), output = flops_counter.TensorSize([1, 64, 256, 256])
#   (bn1): BatchNorm2d(num_features=64), FLOPs = 25,165,824, input = flops_counter.TensorSize([1, 64, 256, 256]), output = flops_counter.TensorSize([1, 64, 256, 256])
#   (relu): ReLU(inplace=True), FLOPs = 8,388,608, input = flops_counter.TensorSize([1, 64, 256, 256]), output = flops_counter.TensorSize([1, 64, 256, 256])
#   (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)), FLOPs = 9,437,184, input = flops_counter.TensorSize([1, 64, 256, 256]), output = flops_counter.TensorSize([1, 64, 128, 128])
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), bias=False), FLOPs = 133,169,152, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (bn1): BatchNorm2d(num_features=64), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,206,910,976, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (bn2): BatchNorm2d(num_features=64), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), bias=False), FLOPs = 532,676,608, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (bn3): BatchNorm2d(num_features=256), FLOPs = 25,165,824, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (relu): ReLU(inplace=True), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), bias=False), FLOPs = 532,676,608, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#         (1): BatchNorm2d(num_features=256), FLOPs = 25,165,824, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       ), FLOPs = 557,842,432, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (eltadd): EltAdd(), FLOPs = 4,194,304, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#     ), FLOPs = 2,485,125,120, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (bn1): BatchNorm2d(num_features=64), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,206,910,976, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (bn2): BatchNorm2d(num_features=64), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), bias=False), FLOPs = 532,676,608, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (bn3): BatchNorm2d(num_features=256), FLOPs = 25,165,824, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (relu): ReLU(inplace=True), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (eltadd): EltAdd(), FLOPs = 4,194,304, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#     ), FLOPs = 2,329,935,872, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (bn1): BatchNorm2d(num_features=64), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,206,910,976, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (bn2): BatchNorm2d(num_features=64), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 64, 128, 128])
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), bias=False), FLOPs = 532,676,608, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (bn3): BatchNorm2d(num_features=256), FLOPs = 25,165,824, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (relu): ReLU(inplace=True), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#       (eltadd): EltAdd(), FLOPs = 4,194,304, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#     ), FLOPs = 2,329,935,872, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   ), FLOPs = 7,144,996,864, input = flops_counter.TensorSize([1, 64, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), bias=False), FLOPs = 1,071,644,672, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 128, 128, 128])
#       (bn1): BatchNorm2d(num_features=128), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 128, 128, 128]), output = flops_counter.TensorSize([1, 128, 128, 128])
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False), FLOPs = 1,207,435,264, input = flops_counter.TensorSize([1, 128, 128, 128]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn2): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), bias=False), FLOPs = 534,773,760, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (bn3): BatchNorm2d(num_features=512), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (relu): ReLU(inplace=True), FLOPs = 9,437,184, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False), FLOPs = 1,071,644,672, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 512, 64, 64])
#         (1): BatchNorm2d(num_features=512), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       ), FLOPs = 1,084,227,584, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (eltadd): EltAdd(), FLOPs = 2,097,152, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     ), FLOPs = 3,937,927,168, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), bias=False), FLOPs = 536,346,624, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn1): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,435,264, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn2): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), bias=False), FLOPs = 534,773,760, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (bn3): BatchNorm2d(num_features=512), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (relu): ReLU(inplace=True), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (eltadd): EltAdd(), FLOPs = 2,097,152, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     ), FLOPs = 2,305,818,624, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), bias=False), FLOPs = 536,346,624, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn1): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,435,264, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn2): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), bias=False), FLOPs = 534,773,760, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (bn3): BatchNorm2d(num_features=512), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (relu): ReLU(inplace=True), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (eltadd): EltAdd(), FLOPs = 2,097,152, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     ), FLOPs = 2,305,818,624, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), bias=False), FLOPs = 536,346,624, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn1): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,435,264, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (bn2): BatchNorm2d(num_features=128), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 128, 64, 64])
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), bias=False), FLOPs = 534,773,760, input = flops_counter.TensorSize([1, 128, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (bn3): BatchNorm2d(num_features=512), FLOPs = 12,582,912, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (relu): ReLU(inplace=True), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#       (eltadd): EltAdd(), FLOPs = 2,097,152, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#     ), FLOPs = 2,305,818,624, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 512, 64, 64])
#   ), FLOPs = 10,855,383,040, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 512, 64, 64])
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), bias=False), FLOPs = 1,072,693,248, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       (bn1): BatchNorm2d(num_features=256), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False), FLOPs = 1,207,697,408, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn2): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (bn3): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (relu): ReLU(inplace=True), FLOPs = 4,718,592, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False), FLOPs = 1,072,693,248, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#         (1): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       ), FLOPs = 1,078,984,704, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (eltadd): EltAdd(), FLOPs = 1,048,576, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     ), FLOPs = 3,915,120,640, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), bias=False), FLOPs = 536,608,768, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn1): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,697,408, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn2): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (bn3): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (relu): ReLU(inplace=True), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (eltadd): EltAdd(), FLOPs = 1,048,576, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     ), FLOPs = 2,293,760,000, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), bias=False), FLOPs = 536,608,768, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn1): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,697,408, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn2): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (bn3): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (relu): ReLU(inplace=True), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (eltadd): EltAdd(), FLOPs = 1,048,576, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     ), FLOPs = 2,293,760,000, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), bias=False), FLOPs = 536,608,768, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn1): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,697,408, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn2): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (bn3): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (relu): ReLU(inplace=True), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (eltadd): EltAdd(), FLOPs = 1,048,576, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     ), FLOPs = 2,293,760,000, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), bias=False), FLOPs = 536,608,768, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn1): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,697,408, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn2): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (bn3): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (relu): ReLU(inplace=True), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (eltadd): EltAdd(), FLOPs = 1,048,576, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     ), FLOPs = 2,293,760,000, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), bias=False), FLOPs = 536,608,768, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn1): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,697,408, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (bn2): BatchNorm2d(num_features=256), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), bias=False), FLOPs = 535,822,336, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (bn3): BatchNorm2d(num_features=1024), FLOPs = 6,291,456, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (relu): ReLU(inplace=True), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#       (eltadd): EltAdd(), FLOPs = 1,048,576, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#     ), FLOPs = 2,293,760,000, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#   ), FLOPs = 15,383,920,640, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 1024, 32, 32])
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), bias=False), FLOPs = 1,073,217,536, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 512, 32, 32])
#       (bn1): BatchNorm2d(num_features=512), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 512, 32, 32]), output = flops_counter.TensorSize([1, 512, 32, 32])
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False), FLOPs = 1,207,828,480, input = flops_counter.TensorSize([1, 512, 32, 32]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (bn2): BatchNorm2d(num_features=512), FLOPs = 786,432, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), bias=False), FLOPs = 536,346,624, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (bn3): BatchNorm2d(num_features=2048), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (relu): ReLU(inplace=True), FLOPs = 2,359,296, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False), FLOPs = 1,073,217,536, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#         (1): BatchNorm2d(num_features=2048), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       ), FLOPs = 1,076,363,264, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (eltadd): EltAdd(), FLOPs = 524,288, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#     ), FLOPs = 3,903,717,376, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), bias=False), FLOPs = 536,739,840, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (bn1): BatchNorm2d(num_features=512), FLOPs = 786,432, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,828,480, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (bn2): BatchNorm2d(num_features=512), FLOPs = 786,432, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), bias=False), FLOPs = 536,346,624, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (bn3): BatchNorm2d(num_features=2048), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (relu): ReLU(inplace=True), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (eltadd): EltAdd(), FLOPs = 524,288, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#     ), FLOPs = 2,287,730,688, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), bias=False), FLOPs = 536,739,840, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (bn1): BatchNorm2d(num_features=512), FLOPs = 786,432, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), padding=(1, 1), bias=False), FLOPs = 1,207,828,480, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (bn2): BatchNorm2d(num_features=512), FLOPs = 786,432, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 512, 16, 16])
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), bias=False), FLOPs = 536,346,624, input = flops_counter.TensorSize([1, 512, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (bn3): BatchNorm2d(num_features=2048), FLOPs = 3,145,728, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (relu): ReLU(inplace=True), FLOPs = 1,572,864, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#       (eltadd): EltAdd(), FLOPs = 524,288, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#     ), FLOPs = 2,287,730,688, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#   ), FLOPs = 8,479,178,752, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 2048, 16, 16])
#   (layer5): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)), FLOPs = 2,415,919,104, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 1024, 8, 8])
#   (layer6): Conv2d(1024, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)), FLOPs = 75,497,472, input = flops_counter.TensorSize([1, 1024, 8, 8]), output = flops_counter.TensorSize([1, 256, 4, 4])
#   (c5_lateral): Conv2d(2048, 256, kernel_size=(1, 1)), FLOPs = 268,435,456, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 256, 16, 16])
#   (c4_lateral): Conv2d(1024, 256, kernel_size=(1, 1)), FLOPs = 536,870,912, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#   (c3_lateral): Conv2d(512, 256, kernel_size=(1, 1)), FLOPs = 1,073,741,824, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   (c2_lateral): Conv2d(256, 256, kernel_size=(1, 1)), FLOPs = 2,147,483,648, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   (eltadd): EltAdd(), FLOPs = 5,505,024, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   (upsample): Upsample(scale_factor=(2, 2), mode=bilinear, align_corners=False), FLOPs = 53,673,984, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   (p7_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)), FLOPs = 18,874,368, input = flops_counter.TensorSize([1, 256, 8, 8]), output = flops_counter.TensorSize([1, 256, 4, 4])
#   (p6_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)), FLOPs = 75,497,472, input = flops_counter.TensorSize([1, 256, 16, 16]), output = flops_counter.TensorSize([1, 256, 8, 8])
#   (p5_conv): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 301,989,888, input = flops_counter.TensorSize([1, 256, 16, 16]), output = flops_counter.TensorSize([1, 256, 16, 16])
#   (p4_conv): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 1,207,959,552, input = flops_counter.TensorSize([1, 256, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#   (p3_conv): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 4,831,838,208, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   (p2_conv): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 19,327,352,832, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   (c7_conv): Conv2d(256, 256, kernel_size=(1, 1)), FLOPs = 2,097,152, input = flops_counter.TensorSize([1, 256, 4, 4]), output = flops_counter.TensorSize([1, 256, 4, 4])
#   (c6_conv): Conv2d(1024, 256, kernel_size=(1, 1)), FLOPs = 33,554,432, input = flops_counter.TensorSize([1, 1024, 8, 8]), output = flops_counter.TensorSize([1, 256, 8, 8])
#   (c5_conv): Conv2d(2048, 256, kernel_size=(1, 1)), FLOPs = 268,435,456, input = flops_counter.TensorSize([1, 2048, 16, 16]), output = flops_counter.TensorSize([1, 256, 16, 16])
#   (c4_conv): Conv2d(1024, 256, kernel_size=(1, 1)), FLOPs = 536,870,912, input = flops_counter.TensorSize([1, 1024, 32, 32]), output = flops_counter.TensorSize([1, 256, 32, 32])
#   (c3_conv): Conv2d(512, 256, kernel_size=(1, 1)), FLOPs = 1,073,741,824, input = flops_counter.TensorSize([1, 512, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   (c2_conv): Conv2d(256, 256, kernel_size=(1, 1)), FLOPs = 2,147,483,648, input = flops_counter.TensorSize([1, 256, 128, 128]), output = flops_counter.TensorSize([1, 256, 128, 128])
#   (cls_subnet): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 24,159,191,040, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (1): ReLU(inplace=True), FLOPs = 10,485,760, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (2): RFE(
#       (branch0): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(1, 5), padding=(0, 2)), FLOPs = 838,860,800, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       ), FLOPs = 1,685,585,920, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       (branch1): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(5, 1), padding=(2, 0)), FLOPs = 838,860,800, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       ), FLOPs = 1,685,585,920, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       (branch2): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(1, 3), padding=(0, 1)), FLOPs = 503,316,480, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       ), FLOPs = 1,350,041,600, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       (branch3): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(3, 1), padding=(1, 0)), FLOPs = 503,316,480, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       ), FLOPs = 1,350,041,600, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       (cated_conv): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(1, 1)), FLOPs = 2,684,354,560, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 10,485,760, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       ), FLOPs = 2,694,840,320, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       (eltadd): EltAdd(), FLOPs = 5,242,880, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     ), FLOPs = 8,771,338,240, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (3): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 24,159,191,040, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (4): ReLU(inplace=True), FLOPs = 10,485,760, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   ), FLOPs = 57,110,691,840, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   (box_subnet): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 24,159,191,040, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (1): ReLU(inplace=True), FLOPs = 10,485,760, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (2): RFE(
#       (branch0): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(1, 5), padding=(0, 2)), FLOPs = 838,860,800, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       ), FLOPs = 1,685,585,920, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       (branch1): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(5, 1), padding=(2, 0)), FLOPs = 838,860,800, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       ), FLOPs = 1,685,585,920, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       (branch2): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(1, 3), padding=(0, 1)), FLOPs = 503,316,480, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       ), FLOPs = 1,350,041,600, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       (branch3): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1)), FLOPs = 671,088,640, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (2): Conv2d(64, 64, kernel_size=(3, 1), padding=(1, 0)), FLOPs = 503,316,480, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (3): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (4): Conv2d(64, 64, kernel_size=(1, 1)), FLOPs = 167,772,160, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#         (5): ReLU(inplace=True), FLOPs = 2,621,440, input = flops_counter.TensorSize([1, 64, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       ), FLOPs = 1,350,041,600, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 64, 64, 64])
#       (cated_conv): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(1, 1)), FLOPs = 2,684,354,560, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#         (1): ReLU(inplace=True), FLOPs = 10,485,760, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       ), FLOPs = 2,694,840,320, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#       (eltadd): EltAdd(), FLOPs = 5,242,880, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     ), FLOPs = 8,771,338,240, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (3): Conv2d(256, 256, kernel_size=(3, 3), padding=(1, 1)), FLOPs = 24,159,191,040, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#     (4): ReLU(inplace=True), FLOPs = 10,485,760, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   ), FLOPs = 57,110,691,840, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 256, 64, 64])
#   (cls_subnet_pred): Conv2d(256, 2, kernel_size=(1, 1)), FLOPs = 20,971,520, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 2, 64, 64])
#   (box_subnet_pred): Conv2d(256, 8, kernel_size=(1, 1)), FLOPs = 83,886,080, input = flops_counter.TensorSize([1, 256, 64, 64]), output = flops_counter.TensorSize([1, 8, 64, 64])
#   (sigmoid): Sigmoid()
# ), FLOPs = 193,864,466,432, input = flops_counter.TensorSize([1, 3, 512, 512]), output = None
